# %%
from datetime import datetime

class Airport:
    def __init__(self, name):
        self.name = name
        self.flights = []

    def getName(self):
        return self.name

    def getFlights(self):
        return self.flights

# %%
class Passenger:
    def __init__(self, name, ticketNumber, seatNumber):
        self.name = name
        self.ticketNumber = ticketNumber
        self.seatNumber = seatNumber

    def getName(self):
        return self.name

    def getTicketNumber(self):
        return self.ticketNumber

    def getSeatNumber(self):
        return self.seatNumber

    def setName(self, name):
        self.name = name

    def setTicketNumber(self, ticketNumber):
        self.ticketNumber = ticketNumber

    def setSeatNumber(self, seatNumber):
        self.seatNumber = seatNumber

# %%
class Flight:
    def __init__(self, flightNumber, departureAirport, destinationAirport, departureDateTime, arrivalDateTime, gate):
        self.flightNumber = flightNumber
        self.departureAirport = departureAirport
        self.destinationAirport = destinationAirport
        self.departureDateTime = departureDateTime
        self.arrivalDateTime = arrivalDateTime
        self.gate = gate

    def getFlightNumber(self):
        return self.flightNumber

    def getDepartureAirport(self):
        return self.departureAirport

    def getDestinationAirport(self):
        return self.destinationAirport

    def getDepartureDateTime(self):
        return self.departureDateTime

    def getArrivalDateTime(self):
        return self.arrivalDateTime

    def getGate(self):
        return self.gate

    def setFlightNumber(self, flightNumber):
        self.flightNumber = flightNumber

    def setDepartureAirport(self, departureAirport):
        self.departureAirport = departureAirport

    def setDestinationAirport(self, destinationAirport):
        self.destinationAirport = destinationAirport

    def setDepartureDateTime(self, departureDateTime):
        self.departureDateTime = departureDateTime

    def setArrivalDateTime(self, arrivalDateTime):
        self.arrivalDateTime = arrivalDateTime

    def setGate(self, gate):
        self.gate = gate

# %%
class BoardingPassSystem:
    def __init__(self, passengerName, flightNumber, departureAirport, destinationAirport, arrivalDateTime, gate, seatNumber, electronicTicket):
        self.passengerName = passengerName
        self.flightNumber = flightNumber
        self.departureAirport = departureAirport
        self.destinationAirport = destinationAirport
        self.arrivalDateTime = arrivalDateTime
        self.gate = gate
        self.seatNumber = seatNumber
        self.electronicTicket = electronicTicket

    def getPassengerName(self):
        return self.passengerName

    def getFlightNumber(self):
        return self.flightNumber

    def getDepartureAirport(self):
        return self.departureAirport

    def getDestinationAirport(self):
        return self.destinationAirport

    def getArrivalDateTime(self):
        return self.arrivalDateTime

    def getGate(self):
        return self.gate

    def getSeatNumber(self):
        return self.seatNumber

    def getElectronicTicket(self):
        return self.electronicTicket

    def setPassengerName(self, passengerName):
        self.passengerName = passengerName

    def setFlightNumber(self, flightNumber):
        self.flightNumber = flightNumber

    def setDepartureAirport(self, departureAirport):
        self.departureAirport = departureAirport

    def setDestinationAirport(self, destinationAirport):
        self.destinationAirport = destinationAirport

    def setArrivalDateTime(self, arrivalDateTime):
        self.arrivalDateTime = arrivalDateTime

    def setGate(self, gate):
        self.gate = gate

    def setSeatNumber(self, seatNumber):
        self.seatNumber = seatNumber

    def setElectronicTicket(self, electronicTicket):
        self.electronicTicket = electronicTicket

# %%
# Test Case 1: Complete Passenger Details
passenger = Passenger("Mohammad", "TS123456", "09A")
print("Test Case 1: Complete Passenger Details")
print("Name:", passenger.getName())
print("Ticket Number:", passenger.getTicketNumber())
print("Seat Number:", passenger.getSeatNumber())

# Test Case 2: Incomplete Passenger Details
passenger = Passenger("Mohammad", "TS123456", "")
print("\nTest Case 2: Incomplete Passenger Details")
if passenger.getSeatNumber():
    print("Name:", passenger.getName())
    print("Ticket Number:", passenger.getTicketNumber())
    print("Seat Number:", passenger.getSeatNumber())
else:
    print("Incomplete passenger details. No boarding pass generated.")

# Test Case 3: Complete Flight Details
flight = Flight("NA4321", "Chicago", "New York", datetime(2022, 12, 6, 11, 40), datetime(2022, 12, 6, 13, 30), "03")
print("\nTest Case 3: Complete Flight Details")
print("Flight Number:", flight.getFlightNumber())
print("Departure Airport:", flight.getDepartureAirport())
print("Destination Airport:", flight.getDestinationAirport())
print("Departure Date and Time:", flight.getDepartureDateTime())
print("Arrival Date and Time:", flight.getArrivalDateTime())
print("Gate:", flight.getGate())

# Complete Boarding Pass Information
boarding_pass = BoardingPassSystem(passenger.getName(), flight.getFlightNumber(), flight.getDepartureAirport(), 
                                    flight.getDestinationAirport(), flight.getArrivalDateTime(), flight.getGate(), 
                                    passenger.getSeatNumber(), passenger.getTicketNumber())

print("\n\n\t\tDetail of the Boarding Pass")
print("Passenger:", boarding_pass.getPassengerName())
print("Flight:", boarding_pass.getFlightNumber())
print("Departure Airport:", boarding_pass.getDepartureAirport())
print("Destination Airport:", boarding_pass.getDestinationAirport())
print("Arrival Time:", boarding_pass.getArrivalDateTime())
print("Gate:", boarding_pass.getGate())
print("Seat Number:", boarding_pass.getSeatNumber())
print("Electronic Ticket:", boarding_pass.getElectronicTicket())
# Out:
# Test Case 1: Complete Passenger Details
# Name: Mohammad
# Ticket Number: TS123456
# Seat Number: 09A
#
# Test Case 2: Incomplete Passenger Details
# Incomplete passenger details. No boarding pass generated.
#
# Test Case 3: Complete Flight Details
# Flight Number: NA4321
# Departure Airport: Chicago
# Destination Airport: New York
# Departure Date and Time: 2022-12-06 11:40:00
# Arrival Date and Time: 2022-12-06 13:30:00
# Gate: 03
#
#
# 		Detail of the Boarding Pass
# Passenger: Mohammad
# Flight: NA4321
# Departure Airport: Chicago
# Destination Airport: New York
# Arrival Time: 2022-12-06 13:30:00
# Gate: 03
# Seat Number:
# Electronic Ticket: TS123456
